# %%
import numpy as np
import pandas as pd
import pickle
from itertools import chain

# %%
with open('./all_posts.pkl', 'rb') as f:
    posts = pickle.load(f)

# %% [markdown]
# 0. Default Index
# 1. Post cid: the @cid number
# 2. Type (Post | Instructor Note): 0 if student initiated post; 1 if instrcutor note
# 3. Subject
# 4. Content
# 5. Student Answer
# 6. Instructor Answer
# 7. Followup (Piled in a big string)

# %%
# %load eecs-instructor-answers/answer_finder.py
import html2text

def parse(x):
    return html2text.html2text(x).replace('\n',' ')

def _is_instructor_note(post):
    return 'instructor-note' in post['tags']

def _get_cid(post):
    return post['nr']

def extract(post):
    """
    0. Post time
    1. Post cid: the @cid number
    2. Type (Post | Instructor Note): 0 if student initiated post; 1 if instrcutor note
    3. Subject
    4. Content
    5. Student Answer
    6. Instructor Answer
    7. Followup (Piled in a big string)
    """
    return {
        'time': _get_post_time(post),
        'cid': _get_cid(post),
        'type': int(_is_instructor_note(post)),
        'subject': _get_post_subject(post),
        'content': _get_post_content(post),
        's_answer': _get_student_answer(post),
        'i_answer': _get_instructor_answer(post),
        'followup': _get_followup_joined(post)
    }


def _get_post_subject(post):
    return parse(post['history'][0]['subject'])

def _get_post_content(post):
    return parse(post['history'][0]['content'])

def _get_post_time(post):
    return post['history'][0]['created']

def _get_student_answer(post):
    s_answers = [ans for ans in post['children'] if ans['type'] == 's_answer']
    if len(s_answers) == 0:
        return None
    else:
        return parse(s_answers[0]['history'][0]['content'])

def _get_instructor_answer(post):
    i_answers = [ans for ans in post['children'] if ans['type'] == 'i_answer']
    if len(i_answers) == 0:
        return None
    else:
        return parse(i_answers[0]['history'][0]['content'])
    
def _get_followup_joined(post):
    return '\n'.join(chain.from_iterable(_get_followup(post)))
    
def _get_followup(post):
    follow_ups = [f for f in post['children'] if f['type'] == 'followup']
    
    result = []
    for f in follow_ups:        
        f_subject = parse(f['subject'])
        f_children = f['children'][::-1]
        
        if f['children'] != []:
            children_subjects = []
            for c in f_children:
                c_subject = parse(c['subject'])  
                children_subjects.append(c_subject)
            result.append([f_subject] + children_subjects)
        else:
            result.append([f_subject])
    return result

# %%
df = pd.DataFrame([extract(post) for post in posts])

# %%
df.head()
# Out:
#     cid                                            content  \
# 0  5851  Hi everyone, I hope you are enjoying winter br...
# 1  5821  **Help the EECS Department & Win Amazon Gift C...
# 2  5790  **The CS side did such a nice job of breaking ...
# 3  5750  The CS Advising Office will be closed for advi...
# 4  5737  For the CS major, students may transfer up to ...
#
#                                             followup i_answer s_answer  \
# 0  I completely agree with this post. Lately the ...     None     None
# 1                                                        None     None
# 2                                                        None     None
# 3                                                        None     None
# 4  Is this for EECS upper divs? Or does it also l...     None     None
#
#                                              subject                  time  \
# 0                                 Piazza Etiquette    2017-12-31T08:52:02Z
# 1           12.22.2017 Undergraduate Announcements    2017-12-22T17:42:33Z
# 2                   EE/EECS Course Enrollment Tips    2017-12-18T20:58:02Z
# 3                             LSCS Winter Schedule    2017-12-11T17:18:29Z
# 4  new policy regarding transferring study abroad...  2017-12-11T16:39:53Z
#
#    type
# 0     0
# 1     1
# 2     1
# 3     1
# 4     1

# %%
df['time'] = pd.DatetimeIndex(df['time'])
df.head()
# Out:
#     cid                                            content  \
# 0  5851  Hi everyone, I hope you are enjoying winter br...
# 1  5821  **Help the EECS Department & Win Amazon Gift C...
# 2  5790  **The CS side did such a nice job of breaking ...
# 3  5750  The CS Advising Office will be closed for advi...
# 4  5737  For the CS major, students may transfer up to ...
#
#                                             followup i_answer s_answer  \
# 0  I completely agree with this post. Lately the ...     None     None
# 1                                                        None     None
# 2                                                        None     None
# 3                                                        None     None
# 4  Is this for EECS upper divs? Or does it also l...     None     None
#
#                                              subject                time  type
# 0                                 Piazza Etiquette   2017-12-31 08:52:02     0
# 1           12.22.2017 Undergraduate Announcements   2017-12-22 17:42:33     1
# 2                   EE/EECS Course Enrollment Tips   2017-12-18 20:58:02     1
# 3                             LSCS Winter Schedule   2017-12-11 17:18:29     1
# 4  new policy regarding transferring study abroad... 2017-12-11 16:39:53     1

# %%
df.sort_values('cid', axis=0, ascending=False)
# Out:
#        cid                                            content  \
# 39    5874           Will CS 169 be offered in Spring 2018?
# 40    5873  How can I view my discussion waitlist position...
# 41    5872  I'm a CS major and I intend to take EE126 and ...
# 42    5871  When I tried to change the discussion session ...
# 43    5870  I'm looking into doing majors in LSCS, Stats, ...
# 44    5868  I'm trying to enroll in a CS class with a time...
# 45    5867  Can someone give some more information on CS 1...
# 46    5866  Can I use CS 100 to fulfill one of the upper d...
# 47    5865  Hopefully this can offer us some insight into ...
# 48    5864  I just tried to swap my 16b lab to a different...
# 49    5863  I'm not sure if this is the right place to ask...
# 50    5862  I know that EE16B has been webcasted for the p...
# 51    5861  Hi,  I am an EECS major and an international s...
# 52    5860  Hi everyone, I received an email yesterday wit...
# 53    5859  I haven't received any signs of me being decla...
# 54    5858  Grades for this course are missing on calcentr...
# 55    5857  I will be taking CS 189 next semester and I wa...
# 56    5856  I submitted my cs189 late-drop form to L&S in ...
# 57    5855  Im current a freshman. I definitely want to TA...
# 58    5854   not expecting to get on it, just want to know.
# 59    5852                 Has TA hiring completed for 61A?
# 0     5851  Hi everyone, I hope you are enjoying winter br...
# 60    5850  hi,  ive taken physics 7b, ee16a, and ee16b. I...
# 61    5849  I'm an L&S CS major who is planning to take a ...
# 62    5848  Hi,  I am trying to enroll in CS 294-131 next ...
# 63    5847  I plan to take CS170 and 189 next semester, bu...
# 64    5846  Just as the title says. I just want to get an ...
# 65    5845  As the title says. Just want to see if I'm mis...
# 66    5844  I'm currently in my last two semesters at Berk...
# 67    5843  For the EECS and EMS majors, is it possible to...
# ...    ...                                                ...
# 5310    35  I've got two classes which require being able ...
# 5313    34     Does this count as an upper-div CS elective?
# 5314    32                  Is there a fix for this coming?
# 5321    31  I am trying to submit the TA app but have been...
# 5320    30  Hi, I made a followup on the @25 post, but I t...
# 5319    29  Hi!  I edited this post because I saw my answe...
# 5318    28  Hi all,  So it turns out I'm a junior and I ca...
# 5317    27  On the Information for GSIs and Readers page (...
# 5316    26  A lot of upperdiv EE classes list EE 20 or EE4...
# 5315    25  According to the Schedule of Classes, enrollme...
# 5328    24  Are there any plans to offer EE 16A/B over Sum...
# 5329    23  [The schedule.berkeley.edu page for CS186](htt...
# 5327    22  [The schedule.berkeley.edu page for CS160](htt...
# 5324    21  Does anybody know how to register for discussi...
# 5326    20  For LS CS major, what is going to be the gradu...
# 5325    19  Occasionally we have students in the EECS depa...
# 5323    18  Is there something that can be done about thei...
# 5322    17  In CS150/EE141, since the class was combined i...
# 5332    16  The trend seems to be that many of the theory ...
# 5331    15       They will be offered until Fall 15, right?
# 5330    14  Do I need to Phase 1 or is it okay to waitlist...
# 5333    13  ************Applications are NOW being accepte...
# 5334    11  Greetings CS Majors,  Tele-Bears for Spring 20...
# 5337    10  The Center for Access to Engineering Excellenc...
# 5336     9  **Deadline to Add & Drop Courses is tomorrow—F...
# 5335     8  Students,      Welcome to the EECS departmenta...
# 5338     7                      How do I drop this "class"?
# 5339     6  Dear EECS Students;  On behalf of EECS chair T...
# 19       5                                             #pin
# 5340     1  Piazza is a Q&A; platform designed to get you ...
#
#                                                followup  \
# 39
# 40
# 41    Thank you so much professor! I was originally ...
# 42
# 43
# 44
# 45
# 46
# 47    I’m all for Piazza solution but this poll is b...
# 48
# 49    Has your payment appeared on the My Finances t...
# 50    In Sprint 2017, EE16B was webcasted, but compl...
# 51    +1 to the Students' answer. I think a lot of s...
# 52    @Nico, this is OP here. I definitely do meet t...
# 53
# 54    what is a 300 series class?  I know 000 series...
# 55    Could you clarify/elaborate on your concerns r...
# 56
# 57
# 58    Not sure on this year, but Honors to Date, a t...
# 59
# 0     I completely agree with this post. Lately the ...
# 60    Are you considering a double major in Physics ...
# 61
# 62
# 63    170 does not plan on offering alternate finals...
# 64
# 65
# 66       Same anon that posted the question - thanks!
# 67    What do you mean Thomas? No matter EECS adviso...
# ...                                                 ...
# 5310  Or, if it is possible, if some of us could be ...
# 5313
# 5314  Any updates?  \n+1  \nIs it safe to phase II C...
# 5321  hmm. That does not seem to solve my problem. B...
# 5320  But why is the lecture capacity more than twic...
# 5319
# 5318  The courses that seem to allow me only let me ...
# 5317  RIP  \nThanks, for some reason my CalNet doesn...
# 5316
# 5315  Speaking of EE 40 enrollment, why is it that t...
# 5328  is it possible EE20 be offered in Summer 15?  ...
# 5329  I recommend the department to reserve certain ...
# 5327  What was Eric Paulos' reasoning for setting F1...
# 5324
# 5326
# 5325
# 5323  For anyone interested,  EE122 prof mentioned t...
# 5322  The lab for the alternate course has been appr...
# 5332  Anything is possible but the department does n...
# 5331  Do we know who's teaching ee 40 in Fall 2015? ...
# 5330  Where is the application?  \n<https://docs.goo...
# 5333  It doesn't have an option for UGSI...  \nThank...
# 5334  I received an error while trying to register f...
# 5337  may I ask what is the pay rate?  \nHourly rate...
# 5336
# 5335
# 5338  This class made me create a new piazza account...
# 5339  What are my chances of getting into EE16A next...
# 19
# 5340
#
#                                                i_answer  \
# 39                                                 None
# 40                                                 None
# 41    126 needs multiple integrals and coordinate ch...
# 42                                                 None
# 43                                                 None
# 44                                                 None
# 45                                                 None
# 46                                                 None
# 47                                                 None
# 48                                                 None
# 49                                                 None
# 50                                                 None
# 51    Take the new H7 series, AKA 5ABC along with th...
# 52                                                 None
# 53                                                 None
# 54                                                 None
# 55    The thing to do is to review your knowledge an...
# 56                                                 None
# 57                                                 None
# 58                                                 None
# 59                                                 None
# 0                                                  None
# 60                                                 None
# 61    Students answer is incorrect, they did not rev...
# 62    *Probably more than 36 hours since it's been t...
# 63                                                 None
# 64                                                 None
# 65                                                 None
# 66                                                 None
# 67                       Answered in my email to you.
# ...                                                 ...
# 5310  This is the message I received from INST:  We ...
# 5313  Hello,  Unfortunately no, this class is not te...
# 5314  Given the enrollment pressures on CS70 for Spr...
# 5321                                               None
# 5320                                               None
# 5319  EE 20 & 40 will most definitely be offered unt...
# 5318  Please contact your ESS Advisor (Bryan, Sharon...
# 5317  Thank you for pointing out the broken link. As...
# 5316  A message from our faculty team creating the 1...
# 5315  Thanks for bringing this up... this special ti...
# 5328  There are no plans to offer 16A/B this summer,...
# 5329  The waitlist has been significantly expanded. ...
# 5327  Last semester was the first semester --at the ...
# 5324  A number of CS classes will not use telebears ...
# 5326  At this time, the only requirement for the CS ...
# 5325                                               None
# 5323                                               None
# 5322  I'm looking into this and hope to have an answ...
# 5332  This was a response from an instructor: Anythi...
# 5331  Yes, the last term EE 20 and 40 will be offere...
# 5330        Yes, it is ok to waitlist during phase 2.
# 5333                                               None
# 5334                                               None
# 5337                                               None
# 5336                                               None
# 5335                                               None
# 5338                                               None
# 5339                                               None
# 19                                                 None
# 5340                                               None
#
#                                                s_answer  \
# 39                                                 None
# 40                                                 None
# 41                                                 None
# 42                                                 None
# 43                                                 None
# 44                                                 None
# 45    How interesting the class is somewhat depends ...
# 46                                            @3989\.
# 47                                                 None
# 48                                                 None
# 49                                                 None
# 50                                                 None
# 51    In this case, I feel it'd be best if you direc...
# 52    It could be that you don’t meet the prereqs fo...
# 53    @5789  \---  From what I remember when I fille...
# 54                                                 None
# 55                                                 None
# 56                                        @5780 @5738
# 57    1\. Lab assist (and go above and beyond when l...
# 58                                                 None
# 59                                                 None
# 0                                                  None
# 60                                                 None
# 61    The answer is in the link you posted.    * 3 U...
# 62    Did you submit the Enrollment Time Conflict Fo...
# 63    CS170 has been webcasted for the past 4 semest...
# 64                                                 None
# 65       The course is listed as EECS C106AB, not EE.
# 66    As far as I know, Professor Gonzalez has confi...
# 67    @5046  @4141  To the original student answerer...
# ...                                                 ...
# 5310  Full Report from Inst:  https://inst.eecs.berk...
# 5313                                               None
# 5314  The EECS faculty is having ongoing discussion ...
# 5321  I solved this issue by deleting any whitespace...
# 5320  Usually lab space is just more limited. So a l...
# 5319                                              @20
# 5318                                               None
# 5317  ![](https://d1b10bmlvqabco.cloudfront.net/atta...
# 5316                                               None
# 5315                                               None
# 5328                                               None
# 5329  As much as I want the class to be expanded (I'...
# 5327                                               None
# 5324                                               None
# 5326                                Just one of them.
# 5325                                               None
# 5323  Final Exams are assigned by the registrar base...
# 5322                                               None
# 5332                                               None
# 5331                                               @6
# 5330  It is ok to phase II. From the email I sent as...
# 5333                                               None
# 5334                                               None
# 5337                                               None
# 5336                                               None
# 5335                                               None
# 5338  Gear icon in top right => Account/Email Settin...
# 5339                                               None
# 19                                                 None
# 5340                                               None
#
#                                                 subject                time  \
# 39                              CS 169 in Spring 2018   2017-12-31 09:27:09
# 40    Unable to view discussion waitlist position on... 2017-12-31 05:24:28
# 41                    Pre-requisites for EE126/EE127?   2017-12-31 03:03:45
# 42      Enrollment bug when changing discussion time?   2017-12-31 01:28:23
# 43    How does overlapping courses between majors wo... 2017-12-30 23:02:52
# 44                                  CS class conflict   2017-12-30 14:14:19
# 45                                             CS 174   2017-12-30 10:26:06
# 46                                             CS 100   2017-12-30 04:19:51
# 47    Which resources setup help you the most as the... 2017-12-30 04:30:24
# 48                                 16b swapping issue   2017-12-29 23:49:55
# 49                             Cancel for Non Payment   2017-12-29 22:29:35
# 50    Will EE16B have webcast & alternative exam nex... 2017-12-29 21:54:30
# 51                         Can I pass out of Physics?   2017-12-29 21:04:12
# 52                                Administrative drop   2017-12-29 15:16:44
# 53                                     CS Declaration   2017-12-29 06:38:01
# 54             CS375 still does not have final grades   2017-12-29 06:03:55
# 55                           Getting Ready for CS 189   2017-12-29 05:55:26
# 56       Anyone's late change has not been processed?   2017-12-29 05:16:22
# 57                          How does one become a TA?   2017-12-29 04:16:26
# 58    When does the college of engineering deans lis... 2017-12-29 04:14:03
# 59                                         61A Hiring   2017-12-29 02:23:18
# 0                                    Piazza Etiquette   2017-12-31 08:52:02
# 60                                    EE117A Workload   2017-12-28 19:57:21
# 61             EECS classes count towards EECS minor?   2017-12-28 17:19:23
# 62                           CS 294-131 Time Conflict   2017-12-28 16:17:04
# 63             Will CS170 have webcast next semester?   2017-12-28 13:20:24
# 64                  CS162 required/helpful for EE192?   2017-12-28 12:50:08
# 65    EE C106A and 106B not showing up in collegesch... 2017-12-28 11:55:38
# 66                       Data 8 hard req for CS C100?   2017-12-28 09:09:42
# 67       Physics 5 series instead of physics 7 series   2017-12-28 06:35:46
# ...                                                 ...                 ...
# 5310                               Inst is down again   2014-11-10 03:16:28
# 5313                                    Mech Eng 191K   2014-11-04 01:19:39
# 5314                     CS 70 Undeclared Waitlisting   2014-11-03 03:17:40
# 5321                  TA application form email error   2014-11-01 23:02:55
# 5320               EE 40 discussion seats > lab seats   2014-11-01 19:41:38
# 5319                                EE20/40 Fall 2015   2014-10-31 16:21:17
# 5318                     R&C - R1B Requirement. Help!   2014-10-30 20:54:46
# 5317                             UGSI Info: Dead Link   2014-10-30 01:53:00
# 5316                           16A = 20 and 16B = 40?   2014-10-28 19:45:58
# 5315             EE 40 Enrollment: Secondary Sections   2014-10-28 04:18:15
# 5328                         EE 16A/B over the summer   2014-10-24 01:02:06
# 5329                              Please Expand CS186   2014-10-23 14:46:12
# 5327                                CS160 Spring 2015   2014-10-23 06:53:53
# 5324                                  CS170 and CS186   2014-10-20 22:01:57
# 5326                                          EE16A/B   2014-10-20 17:10:45
# 5325                          Interested in tutoring?   2014-10-20 16:03:42
# 5323                                  cs161 and ee122   2014-10-20 02:25:18
# 5322                            CS150/EE141 Lab Class   2014-10-19 23:55:21
# 5332                                 CS 172, 174, 270   2014-10-19 06:30:00
# 5331                                         EE 20/40   2014-10-18 22:42:05
# 5330                                   Phase 1 EE16A?   2014-10-17 02:18:37
# 5333     Apply to be a Spring 2015 UGSI! (Due Nov. 1)   2014-10-08 17:33:32
# 5334  L&S CS (not EECS) Faculty Advising and your Sp... 2014-10-04 03:41:06
# 5337                                We need CS tutors   2014-09-25 23:46:08
# 5336  Reminder: Add/Drop Deadline is Friday, Septemb... 2014-09-25 17:53:44
# 5335                               Welcome to Piazza!   2014-09-22 20:22:02
# 5338                                             Drop   2014-09-19 20:23:22
# 5339                           Update on EE 16A and B   2014-08-18 20:35:45
# 19                              Search for Teammates!   2014-08-11 16:20:58
# 5340                               Welcome to Piazza!   2014-08-11 16:20:57
#
#       type
# 39       0
# 40       0
# 41       0
# 42       0
# 43       0
# 44       0
# 45       0
# 46       0
# 47       0
# 48       0
# 49       0
# 50       0
# 51       0
# 52       0
# 53       0
# 54       0
# 55       0
# 56       0
# 57       0
# 58       0
# 59       0
# 0        0
# 60       0
# 61       0
# 62       0
# 63       0
# 64       0
# 65       0
# 66       0
# 67       0
# ...    ...
# 5310     0
# 5313     0
# 5314     0
# 5321     0
# 5320     0
# 5319     0
# 5318     0
# 5317     0
# 5316     0
# 5315     0
# 5328     0
# 5329     0
# 5327     0
# 5324     0
# 5326     0
# 5325     1
# 5323     0
# 5322     0
# 5332     0
# 5331     0
# 5330     0
# 5333     1
# 5334     1
# 5337     1
# 5336     1
# 5335     1
# 5338     0
# 5339     1
# 19       0
# 5340     0
#
# [5341 rows x 8 columns]

# %%
df.to_pickle('all_content_dataframe.pkl')
